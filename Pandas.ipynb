# %% [markdown]
# <a href="https://colab.research.google.com/github/emznavs/ML-Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Reading in Files in Pandas](https://www.youtube.com/watch?v=dUpyC40cF6Q)

# %%
import pandas as pd

# %%
 df = pd.read_csv('/content/customers-100.csv')

# %%
#df2 = pd.read_table('/content/customers-100.csv')

# %%
#df3 = pd.read_json
#df4 = pd.read_excel
pd.set_option('display.max.rows', 100)

# %%
#df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
df.shape
# Out:
# (100, 12)

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df.tail(10)
# Out:
#     Index      Customer Id First Name Last Name                      Company  \
# 90     91  5ef6d3eefdD43bE       Nina    Chavez                Byrd-Campbell
# 91     92  98b3aeDcC3B9FF3      Shane     Foley                   Rocha-Hart
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers                Lamb-Peterson
# 93     94  54B5B5Fe9F1B6C5     Sherry     Young      Lee, Lucero and Johnson
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas  Newton, Petersen and Mathis
# 95     96  cb8E23e48d22Eae       Karl     Greer                    Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson        Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra                Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer           Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes           Le, Nash and Cross
#
#                 City          Country                Phone 1  \
# ...

# %%
df['Company']
# Out:
# 0                     Rasmussen Group
# 1                         Vega-Gentry
# 2                       Murillo-Perry
# 3     Dominguez, Mcmillan and Donovan
# 4            Martin, Lang and Andrade
# 5                        Steele Group
# 6        Lester, Woodard and Mitchell
# 7        Sanford, Davenport and Giles
# 8                      Browning-Simon
# 9                        Beck-Hendrix
# 10         Oconnell, Meza and Everett
# 11          Hoffman, Reed and Mcclain
# 12                     Graham-Francis
# 13                     Carpenter-Cook
# 14                     Carter-Hancock
# 15                 Singleton and Sons
# 16                    Winters-Mendoza
# 17                      Valentine LLC
# 18                          Simon LLC
# 19                     Mays-Mccormick
# 20                      Patterson Inc
# 21         Manning, Hester and Arroyo
# 22                     Greer and Sons
# 23                    Watts-Donaldson
# 24                         Tucker LLC
# ...

# %%
df.loc[91]
# Out:
# Index                                          92
# Customer Id                       98b3aeDcC3B9FF3
# First Name                                  Shane
# Last Name                                   Foley
# Company                                Rocha-Hart
# City                             South Dannymouth
# Country                                   Hungary
# Phone 1                           +1-822-569-0302
# Phone 2                    001-626-114-5844x55073
# Email                          nsteele@sparks.com
# Subscription Date                      2021-07-06
# Website              https://www.holt-sparks.com/
# Name: 91, dtype: object

# %%
df.iloc[91]
# Out:
# Index                                          92
# Customer Id                       98b3aeDcC3B9FF3
# First Name                                  Shane
# Last Name                                   Foley
# Company                                Rocha-Hart
# City                             South Dannymouth
# Country                                   Hungary
# Phone 1                           +1-822-569-0302
# Phone 2                    001-626-114-5844x55073
# Email                          nsteele@sparks.com
# Subscription Date                      2021-07-06
# Website              https://www.holt-sparks.com/
# Name: 91, dtype: object

# %% [markdown]
# **Filtering and Ordering**

# %%
 df2 = pd.read_csv('/content/Companies.csv')
headers = df2.columns
#headers
df2.head()
# Out:
#    Unnamed: 0  Rank                Name                    Industry  \
# 0           0     1             Walmart                      Retail
# 1           1     2              Amazon  Retail and cloud computing
# 2           2     3          ExxonMobil          Petroleum industry
# 3           3     4               Apple        Electronics industry
# 4           4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                611,289           6.7%  2,100,000  Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000    Seattle, Washington
# 2                413,680          44.8%     62,000          Spring, Texas
# 3                394,328           7.8%    164,000  Cupertino, California
# 4                324,162          12.7%    400,000  Minnetonka, Minnesota

# %%
column_2 = df2.iloc[:, 0]
#column_2
df3 = df2.drop('Unnamed: 0',axis=1)
#df3.head()
Revenue_headers = df3.columns[3]
Revenue_column = df3['Revenue (USD millions)']
#Revenue_column
# Out:
# 0     611,289
# 1     513,983
# 2     413,680
# 3     394,328
# 4     324,162
# 5     322,467
# 6     302,089
# 7     282,836
# 8     276,711
# 9     246,252
# 10    238,587
# 11    226,954
# 12    198,270
# 13    181,364
# 14    180,516
# 15    180,012
# 16    175,702
# 17    171,189
# 18    158,057
# 19    157,403
# 20    156,735
# 21    156,595
# 22    154,792
# 23    148,258
# 24    144,547
# 25    136,835
# 26    132,703
# 27    121,596
# 28    121,427
# 29    120,741
# 30    116,609
# 31    115,053
# 32    109,120
# 33    102,301
# 34    101,556
# 35    101,078
# 36    100,338
# 37    100,330
# 38     97,059
# 39     94,943
# 40     93,512
# 41     92,870
# 42     89,876
# 43     89,328
# 44     86,717
# 45     86,859
# 46     82,859
# 47     82,722
# 48     82,156
# 49     81,462
# 50     80,187
# 51     78,620
# 52     77,650
# 53     76,555
# 54     69,898
# 55     68,711
# 56     68,636
# 57     67,232
# 58     67,074
# 59     66,608
# 60     66,036
# 61     65,984
# ...

# %%
# Convert 'Revenue (USD millions)' column to numeric, handling potential errors
#df3['Revenue (USD millions)'] = pd.to_numeric(df3['Revenue (USD millions)'], errors='coerce')

#df3['Revenue (USD millions)']
# Now perform the comparison
#df3[df3['Revenue (USD millions)'] < 500000]
# Out:
# 'Revenue (USD millions)'

# %%
#df3[df3['Revenue (USD millions)']]
print(df3['Revenue (USD millions)'].dtype)
# Out:
# object

# %%
# Remove any non-numeric characters (like commas or currency symbols)
df3['Revenue (USD millions)'] = df3['Revenue (USD millions)'].replace('[\$,]', '', regex=True)

# Convert to float
df3['Revenue (USD millions)'] = df3['Revenue (USD millions)'].astype(float)

df3['Revenue (USD millions)'] = pd.to_numeric(df3['Revenue (USD millions)'], errors='coerce')

# %%
df3[df3['Revenue (USD millions)'] > 500000]
# Out:
#    Rank     Name                    Industry  Revenue (USD millions)  \
# 0     1  Walmart                      Retail                611289.0
# 1     2   Amazon  Retail and cloud computing                513983.0
#
#   Revenue growth  Employees           Headquarters
# 0           6.7%  2,100,000  Bentonville, Arkansas
# 1           9.4%  1,540,000    Seattle, Washington

# %%
# Out:
#    Rank     Name                    Industry  Revenue (USD millions)  \
# 0     1  Walmart                      Retail                611289.0
# 1     2   Amazon  Retail and cloud computing                513983.0
#
#   Revenue growth  Employees           Headquarters
# 0           6.7%  2,100,000  Bentonville, Arkansas
# 1           9.4%  1,540,000    Seattle, Washington

# %%
df3.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#    Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0                611289.0           6.7%  2,100,000  Bentonville, Arkansas
# 1                513983.0           9.4%  1,540,000    Seattle, Washington
# 2                413680.0          44.8%     62,000          Spring, Texas
# 3                394328.0           7.8%    164,000  Cupertino, California
# 4                324162.0          12.7%    400,000  Minnetonka, Minnesota

# %%
Retail = ['Retail']
df3[df3['Industry'].isin(Retail)]
# Out:
#     Rank                Name Industry  Revenue (USD millions) Revenue growth  \
# 0      1             Walmart   Retail                611289.0           6.7%
# 11    12              Costco   Retail                226954.0          15.8%
# 19    20      The Home Depot   Retail                157403.0           4.1%
# 23    24              Kroger   Retail                148258.0           7.5%
# 32    33  Target Corporation   Retail                109120.0           2.9%
# 38    39              Lowe's   Retail                 97059.0           0.8%
# 52    53          Albertsons   Retail                 77650.0           8.0%
# 79    80              Publix   Retail                 54942.0          13.5%
# 88    89                 TJX   Retail                 49936.0           2.9%
# 95    96            Best Buy   Retail                 46298.0          10.6%
#
#     Employees                 Headquarters
# 0   2,100,000        Bentonville, Arkansas
# ...

# %%
df3[df3['Industry'].str.contains('industry')]
# Out:
#     Rank                          Name                          Industry  \
# 2      3                    ExxonMobil                Petroleum industry
# 3      4                         Apple              Electronics industry
# 9     10           Chevron Corporation                Petroleum industry
# 15    16            Marathon Petroleum                Petroleum industry
# 16    17                   Phillips 66                Petroleum industry
# 17    18                 Valero Energy                Petroleum industry
# 18    19            Ford Motor Company               Automotive industry
# 20    21                General Motors               Automotive industry
# 26    27      Walgreens Boots Alliance           Pharmaceutical industry
# 34    35        Archer Daniels Midland                     Food industry
# 37    38                        Pfizer           Pharmaceutical industry
# 39    40             Johnson & Johnson           Pharmaceutical industry
# ...

# %%
#Set index to Industry
df4 = df3.set_index('Industry')
df4.head()
# Out:
#                             Rank                Name  Revenue (USD millions)  \
# Industry
# Retail                         1             Walmart                611289.0
# Retail and cloud computing     2              Amazon                513983.0
# Petroleum industry             3          ExxonMobil                413680.0
# Electronics industry           4               Apple                394328.0
# Healthcare                     5  UnitedHealth Group                324162.0
#
#                            Revenue growth  Employees           Headquarters
# Industry
# Retail                               6.7%  2,100,000  Bentonville, Arkansas
# Retail and cloud computing           9.4%  1,540,000    Seattle, Washington
# Petroleum industry                  44.8%     62,000          Spring, Texas
# Electronics industry                 7.8%    164,000  Cupertino, California
# Healthcare                          12.7%    400,000  Minnetonka, Minnesota

# %%
df4.filter(items=['Name','Revenue (USD millions)'])
# Out:
#                                                                    Name  \
# Industry
# Retail                                                          Walmart
# Retail and cloud computing                                       Amazon
# Petroleum industry                                           ExxonMobil
# Electronics industry                                              Apple
# Healthcare                                           UnitedHealth Group
# Healthcare                                                   CVS Health
# Conglomerate                                         Berkshire Hathaway
# Technology and cloud computing                                 Alphabet
# Health                                             McKesson Corporation
# Petroleum industry                                  Chevron Corporation
# Pharmacy wholesale                                              Cencora
# Retail                                                           Costco
# ...
